# %%
#牛刀小試
a=3
b=5
print(a+b)
# Out:
# 8

# %%
import requests
t=requests.get('https://zh-tw.facebook.com/')
print(t.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant" id="facebook" class="no_js">
# ...
